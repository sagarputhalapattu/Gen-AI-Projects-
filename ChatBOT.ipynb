# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarputhalapattu/Gen-AI-Projects-/blob/main/ChatBOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import google.generativeai as genai
api_key='AIzaSyBjYhQ6Xzh-M-iySyGrILaTMoJvGW8sIBc'
genai.configure(api_key=api_key)

# %%
# !pip install google-generativeai
# Install the package

# %%
for m in genai.list_models():
  print(m.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision
# models/embedding-001
# models/text-embedding-004
# models/aqa

# %% [markdown]
# model
#
# Text model : gemini-pro

# %%
model=genai.GenerativeModel("gemini-pro-vision")
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-pro-vision',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
# )

# %%
response=model.generate_content("Provied me the meanig of  name 'Sagar'in sanskrit")
print(response.text)
# Out:
# सागर (Sagar)

# %% [markdown]
# ## **Image Model**

# %%
from PIL import Image

# %%
imp=Image.open("/content/Screenshot (5).png")
imp
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080>

# %%
import os
import google.generativeai as genai
api_key='AIzaSyBjYhQ6Xzh-M-iySyGrILaTMoJvGW8sIBc'
genai.configure(api_key=api_key)

model=genai.GenerativeModel("gemini-1.0-pro-vision-latest")
imp=Image.open("/content/Screenshot (5).png")
prompt="tell about the image and which movie from "

response = model.generate_content([prompt,imp])
print(response.parts)
# Out:
# [text: " The image shows a giant red and black creature with four eyes. It is standing in a dark, starry background. The creature is likely from the movie Eternals."
# ]

# %%
import os
import google.generativeai as genai
api_key='AIzaSyBjYhQ6Xzh-M-iySyGrILaTMoJvGW8sIBc'
genai.configure(api_key=api_key)
